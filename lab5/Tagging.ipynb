# %% [markdown]
# ## Morphosyntactic tagging
# Morphosyntactic tagging is one of the core algorithms in NLP. It assigns morphological and (in some languages) syntactic tags to the words in a text. E.g. this allows to distinguish between the major grammatical categories, such as nouns and verbs.

# %%
from tqdm import tqdm
import sys
import os
import requests
from collections import Counter
from numpy import log
from tabulate import tabulate

# %%
def isalpha(s):
    for letter in s:
        if not letter.isalpha():
            return False
    return True

# %%
ustawy_path = '../ustawy'
ustawy_tagged_path = 'tagged_ustawy'

# %%
legislation_acts = {}

with tqdm(total=1179, file=sys.stdout) as pbar: 
    for filename in os.listdir(ustawy_path):
            with open(ustawy_path + '/' + filename, 'r', encoding='utf8') as f:
                content = f.read()
                legislation_acts[filename] = content
                pbar.update(1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 1179/1179 [00:00<00:00, 5878.71it/s]

# %% [markdown]
# ## Use the tool to tag and lemmatize the law corpus.

# %%
def tag_text(text):
    response = requests.post("http://localhost:9200", data=text.encode("utf-8"))
    return response.content.decode("utf-8")

# %%
legislation_acts_tagged = {}

# %%
# with tqdm(total=1179, file=sys.stdout) as pbar:
#     for filename, text in legislation_acts.items():
#         legislation_acts_tagged[filename] = tag_text(text)
#         pbar.update(1)

# %%
# for filename, tagged_content in legislation_acts_tagged.items():
#     with open(ustawy_tagged_path + '/' + filename, 'w+', encoding='utf-8') as f:
#         f.write(tagged_content)

# %%
with tqdm(total=1179, file=sys.stdout) as pbar:
    for filename in os.listdir(ustawy_tagged_path):
            with open(ustawy_tagged_path + '/' + filename, 'r', encoding='utf8') as f:
                tagged_content = f.read()
                legislation_acts_tagged[filename] = tagged_content
                pbar.update(1)
# Out:
# 1180it [00:01, 1075.18it/s]

# %% [markdown]
# ## Using the tagged corpus compute bigram statistic for the tokens containing:
#
# - lemmatized, downcased word
# - morphosyntactic category of the word (subst, fin, adj, etc.)

# %%
def extract_tokens(tagged_text):
    lines = tagged_text.split("\n")
    tokens = [line.strip().split("\t") for line in lines if line.startswith("\t")]
    return [(token[0].lower(), token[1].split(":")[0]) for token in tokens]

# %%
tokens_map = {}

for filename, act in tqdm(legislation_acts_tagged.items()):
    tokens_map[filename] = Counter(extract_tokens(act))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1180/1180 [00:12<00:00, 94.39it/s]

# %%
counter_total = Counter()

for _, counter in tqdm(tokens_map.items()):
    counter_total += counter
    
unigrams_total = Counter({x: count for x, count in counter_total.items() if isalpha(x[0])})    

total = sum(unigrams_total.values())
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 1180/1180 [00:01<00:00, 718.59it/s]

# %%
total
# Out:
# 3582293

# %%
list(unigrams_total.items())[:10]
# Out:
# [(('dziennik', 'brev'), 8635),
#  (('ustawa', 'brev'), 7042),
#  (('z', 'prep'), 87987),
#  (('rok', 'brev'), 33050),
#  (('numer', 'brev'), 44868),
#  (('pozycja', 'brev'), 45197),
#  (('ustawa', 'subst'), 24933),
#  (('dzień', 'subst'), 27885),
#  (('grudzień', 'subst'), 2157),
#  (('o', 'prep'), 64713)]

# %%
bigrams_map = {}

for filename, tokens in tqdm(tokens_map.items()):
    bigrams_map[filename] = []
    previous_token = None
    for token, _ in tokens.items():
        if previous_token is not None:
            bigrams_map[filename].append((previous_token, token))
        previous_token = token
    bigrams_map[filename] = Counter(bigrams_map[filename])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 1180/1180 [00:00<00:00, 3608.30it/s]

# %%
bigrams_total = Counter()

for _, counter in tqdm(bigrams_map.items()):
    bigrams_total += counter

sum(bigrams_total.values())
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1180/1180 [00:14<00:00, 83.42it/s]
# 676685

# %% [markdown]
# ## Discard bigrams containing characters other than letters. Make sure that you discard the invalid entries after computing the bigram counts.

# %%
bigrams_total = Counter({x: count for x, count in bigrams_total.items() if isalpha(x[0][0]) and isalpha(x[1][0])})

# %%
bigrams_total.most_common()[:10]
# Out:
# [((('ustawa', 'brev'), ('z', 'prep')), 946),
#  ((('rok', 'brev'), ('numer', 'brev')), 946),
#  ((('ustawa', 'subst'), ('dzień', 'subst')), 798),
#  ((('o', 'prep'), ('zmiana', 'subst')), 695),
#  ((('wprowadzać', 'fin'), ('się', 'qub')), 560),
#  ((('wchodzić', 'fin'), ('życie', 'subst')), 544),
#  ((('się', 'qub'), ('następujący', 'adj')), 513),
#  ((('otrzymywać', 'fin'), ('brzmienie', 'subst')), 475),
#  ((('zwać', 'ppas'), ('daleko', 'adv')), 446),
#  ((('który', 'adj'), ('mowa', 'subst')), 423)]

# %%
bigrams_number = sum(bigrams_total.values())
bigrams_number
# Out:
# 466717

# %% [markdown]
# ## Compute LLR statistic for this dataset.

# %%
def extract_ngram(result):
    return list(map(lambda x: x[0], result))
def extract_llr(result):
    return list(map(lambda x: x[1], result))

def print_table(bigrams, appender = ''):
    bigram_table = {('bigram ' + appender): extract_ngram(bigrams), 'LLR': extract_llr(bigrams)}
    print(tabulate(bigram_table, headers='keys', tablefmt='fancy_grid'))

# %%
def H(counts):
    total = float(sum(counts))
    return sum([k * log(k / total + (k==0)) for k in counts])


def llr2(word1, word2):
    together_occ = bigrams_total[(word1, word2)]
    k11 = together_occ
    k12 = unigrams_total[word2] - together_occ
    k21 = unigrams_total[word1] - together_occ
    k22 = bigrams_number - k12 - k21 - k11
    
    return 2 * (H([k11, k12, k21, k22]) - H([k11 + k12, k21 + k22]) - H([k11 + k21, k12 + k22]))

# %%
bigrams_total_llr = {bigram: llr2(bigram[0], bigram[1]) for bigram, _  in bigrams_total.items()}

# %%
bigrams_llr_top10 = Counter(bigrams_total_llr).most_common()[:10]

# %%
print_table(bigrams_llr_top10)
# Out:
# ╒══════════════════════════════════════╤══════════╕
# │ bigram                               │      LLR │
# ╞══════════════════════════════════════╪══════════╡
# │ (('w', 'prep'), ('artykuł', 'brev')) │ 109214   │
# ├──────────────────────────────────────┼──────────┤
# │ (('artykuł', 'brev'), ('w', 'prep')) │ 108185   │
# ├──────────────────────────────────────┼──────────┤
# │ (('do', 'prep'), ('w', 'prep'))      │  76064.5 │
# ├──────────────────────────────────────┼──────────┤
# │ (('w', 'prep'), ('ustęp', 'brev'))   │  65854   │
# ├──────────────────────────────────────┼──────────┤
# │ (('który', 'adj'), ('w', 'prep'))    │  60618.5 │
# ├──────────────────────────────────────┼──────────┤
# │ (('lub', 'conj'), ('w', 'prep'))     │  55929.6 │
# ├──────────────────────────────────────┼──────────┤
# │ (('w', 'prep'), ('lub', 'conj'))     │  55929.6 │
# ├──────────────────────────────────────┼──────────┤
# │ (('się', 'qub'), ('w', 'prep'))      │  55898.2 │
# ├──────────────────────────────────────┼──────────┤
# │ (('w', 'prep'), ('oraz', 'conj'))    │  40184.2 │
# ├──────────────────────────────────────┼──────────┤
# │ (('oraz', 'conj'), ('w', 'prep'))    │  40184.2 │
# ╘══════════════════════════════════════╧══════════╛

# %% [markdown]
# ## Partition the entries based on the syntactic categories of the words, i.e. all bigrams having the form of w1:adj w2:subst should be placed in one partition (the order of the words may not be changed).

# %%
partitions = {}

for bigram in tqdm(bigrams_total.keys()):
    key = (bigram[0][1], bigram[1][1])
    if key not in partitions:
        partitions[key] = 1
    else:
        partitions[key] += 1
# Out:
# 100%|█████████████████████████████████████████████████████████████████████| 320432/320432 [00:00<00:00, 1377766.54it/s]

# %%
sorted_partitions = {k: v for k, v in sorted(partitions.items(), key=lambda item: -item[1])}
sorted_partitions
# Out:
# {('subst', 'subst'): 46803,
#  ('adj', 'subst'): 22518,
#  ('subst', 'adj'): 21855,
#  ('ger', 'subst'): 12942,
#  ('subst', 'ger'): 12392,
#  ('adj', 'adj'): 9999,
#  ('subst', 'fin'): 9338,
#  ('subst', 'ppas'): 9148,
#  ('ppas', 'subst'): 9091,
#  ('fin', 'subst'): 8304,
#  ('adj', 'ger'): 5223,
#  ('subst', 'pact'): 5118,
#  ('ger', 'adj'): 4794,
#  ('ger', 'ger'): 4788,
#  ('pact', 'subst'): 4606,
#  ('adj', 'fin'): 4301,
#  ('adj', 'ppas'): 4187,
#  ('inf', 'subst'): 3857,
#  ('ppas', 'adj'): 3438,
#  ('fin', 'adj'): 3418,
#  ('subst', 'inf'): 3163,
#  ('prep', 'subst'): 2771,
#  ('ger', 'fin'): 2639,
#  ('fin', 'ger'): 2619,
#  ('subst', 'prep'): 2515,
#  ('ppas', 'ppas'): 2376,
#  ('adj', 'pact'): 2362,
#  ('ger', 'ppas'): 2309,
#  ('fin', 'fin'): 2239,
#  ('ppas', 'ger'): 2210,
#  ('subst', 'adv'): 2210,
#  ('adv', 'subst'): 2189,
#  ('ppas', 'fin'): 2033,
#  ('subst', 'praet'): 1828,
#  ('fin', 'ppas'): 1824,
#  ('subst', 'conj'): 1809,
#  ('pact', 'adj'): 1793,
#  ('inf', 'adj'): 1675,
#  ('conj', 'subst'): 1580,
#  ('adj', 'inf'): 1580,
#  ('praet', 'subst'): 1542,
#  ('pact', 'ger'): 1476,
#  ('inf', 'ger'): 1313,
#  ('adj', 'prep'): 1243,
#  ('ger', 'pact'): 1149,
#  ('adj', 'adv'): 1116,
#  ('adv', 'adj'): 1103,
#  ('subst', 'brev'): 1072,
#  ('ger', 'inf'): 1052,
#  ('prep', 'adj'): 1034,
#  ('prep', 'ger'): 1002,
#  ('qub', 'subst'): 1000,
#  ('adj', 'conj'): 967,
#  ('inf', 'ppas'): 963,
#  ('ppas', 'adv'): 947,
#  ('subst', 'qub'): 943,
#  ('ppas', 'prep'): 937,
#  ('fin', 'adv'): 925,
#  ('pact', 'fin'): 924,
#  ('brev', 'subst'): 919,
#  ('adv', 'ppas'): 910,
#  ('adj', 'praet'): 867,
#  ('fin', 'inf'): 851,
#  ('fin', 'pact'): 842,
#  ('ppas', 'pact'): 817,
#  ('adv', 'fin'): 812,
#  ('pact', 'ppas'): 800,
#  ('praet', 'adj'): 746,
#  ('inf', 'inf'): 745,
#  ('ppas', 'inf'): 733,
#  ('conj', 'adj'): 722,
#  ('subst', 'pcon'): 664,
#  ('pcon', 'subst'): 660,
#  ('ger', 'adv'): 625,
#  ('pact', 'pact'): 609,
#  ('fin', 'prep'): 600,
#  ('ger', 'prep'): 597,
#  ('inf', 'fin'): 584,
#  ('praet', 'ppas'): 564,
#  ('adv', 'ger'): 562,
#  ('praet', 'ger'): 536,
#  ('adj', 'brev'): 535,
#  ('adj', 'qub'): 535,
#  ('ger', 'praet'): 489,
#  ('pact', 'inf'): 480,
#  ('qub', 'adj'): 476,
#  ('subst', 'adja'): 458,
#  ('prep', 'ppas'): 450,
#  ('inf', 'pact'): 445,
#  ('prep', 'fin'): 436,
#  ('fin', 'praet'): 430,
#  ('conj', 'ger'): 424,
#  ('subst', 'comp'): 408,
#  ('ppas', 'praet'): 406,
#  ('inf', 'adv'): 401,
#  ('adv', 'inf'): 399,
#  ('praet', 'fin'): 396,
#  ('num', 'subst'): 394,
#  ('comp', 'subst'): 384,
#  ('praet', 'praet'): 380,
#  ('subst', 'num'): 378,
#  ('fin', 'qub'): 369,
#  ('imps', 'subst'): 363,
#  ('pact', 'adv'): 345,
#  ('ppas', 'qub'): 336,
#  ('ger', 'conj'): 333,
#  ('subst', 'imps'): 328,
#  ('brev', 'adj'): 320,
#  ('adj', 'pcon'): 317,
#  ('adv', 'adv'): 310,
#  ('adja', 'adj'): 310,
#  ('qub', 'ppas'): 304,
#  ('qub', 'fin'): 290,
#  ('adv', 'pact'): 289,
#  ('conj', 'ppas'): 286,
#  ('pcon', 'adj'): 282,
#  ('conj', 'fin'): 281,
#  ('qub', 'ger'): 276,
#  ('praet', 'inf'): 274,
#  ('fin', 'pcon'): 269,
#  ('ppron3', 'subst'): 268,
#  ('ger', 'qub'): 268,
#  ('qub', 'inf'): 266,
#  ('pact', 'prep'): 265,
#  ('brev', 'fin'): 260,
#  ('inf', 'prep'): 259,
#  ('adv', 'praet'): 254,
#  ('pcon', 'fin'): 254,
#  ('ppas', 'conj'): 244,
#  ('ger', 'pcon'): 243,
#  ('praet', 'adv'): 225,
#  ('prep', 'pact'): 217,
#  ('fin', 'conj'): 210,
#  ('comp', 'fin'): 209,
#  ('inf', 'praet'): 199,
#  ('adj', 'num'): 196,
#  ('adj', 'comp'): 196,
#  ('num', 'adj'): 195,
#  ('inf', 'qub'): 194,
#  ('pact', 'praet'): 193,
#  ('adja', 'subst'): 191,
#  ('adv', 'prep'): 190,
#  ('adj', 'adja'): 187,
#  ('brev', 'ppas'): 183,
#  ('adj', 'imps'): 178,
#  ('imps', 'adj'): 177,
#  ('brev', 'ger'): 166,
#  ('pcon', 'ger'): 166,
#  ('subst', 'ppron3'): 165,
#  ('subst', 'interj'): 164,
#  ('ger', 'imps'): 161,
#  ('fin', 'num'): 158,
#  ('ger', 'brev'): 153,
#  ('interj', 'subst'): 152,
#  ('pred', 'inf'): 152,
#  ('conj', 'pact'): 148,
#  ('comp', 'adj'): 147,
#  ('subst', 'pred'): 147,
#  ('praet', 'qub'): 146,
#  ('praet', 'prep'): 146,
#  ('praet', 'pact'): 145,
#  ('ppas', 'pcon'): 139,
#  ('imps', 'ger'): 137,
#  ('comp', 'praet'): 136,
#  ('qub', 'praet'): 133,
#  ('qub', 'adv'): 131,
#  ('pact', 'qub'): 130,
#  ('prep', 'praet'): 130,
#  ('comp', 'ppas'): 130,
#  ('subst', 'winien'): 130,
#  ('ppas', 'brev'): 129,
#  ('num', 'fin'): 128,
#  ('brev', 'brev'): 127,
#  ('pcon', 'ppas'): 121,
#  ('qub', 'pact'): 120,
#  ('subst', 'xxx'): 120,
#  ('imps', 'fin'): 118,
#  ('xxx', 'subst'): 117,
#  ('prep', 'adv'): 117,
#  ('conj', 'inf'): 114,
#  ('inf', 'pcon'): 111,
#  ('prep', 'inf'): 110,
#  ('fin', 'imps'): 110,
#  ('pcon', 'inf'): 105,
#  ('inf', 'conj'): 103,
#  ('num', 'ppas'): 101,
#  ('fin', 'comp'): 101,
#  ('prep', 'prep'): 100,
#  ('pact', 'conj'): 100,
#  ('conj', 'adv'): 99,
#  ('ppas', 'num'): 99,
#  ('ppas', 'imps'): 98,
#  ('ger', 'comp'): 97,
#  ('adv', 'qub'): 95,
#  ('ppas', 'comp'): 95,
#  ('conj', 'prep'): 93,
#  ('num', 'ger'): 91,
#  ('adv', 'conj'): 90,
#  ('qub', 'prep'): 90,
#  ('comp', 'ger'): 89,
#  ('ger', 'num'): 89,
#  ('brev', 'pact'): 88,
#  ('imps', 'ppas'): 88,
#  ('fin', 'brev'): 86,
#  ('adj', 'interj'): 85,
#  ('ppron3', 'ger'): 84,
#  ('xxx', 'xxx'): 83,
#  ('conj', 'praet'): 78,
#  ('inf', 'comp'): 78,
#  ('winien', 'inf'): 77,
#  ('ger', 'ppron3'): 76,
#  ('pact', 'pcon'): 74,
#  ('pcon', 'adv'): 74,
#  ('adv', 'num'): 73,
#  ('adj', 'pred'): 73,
#  ('imps', 'imps'): 71,
#  ('inf', 'num'): 70,
#  ('pcon', 'pcon'): 65,
#  ('adv', 'imps'): 63,
#  ('subst', 'bedzie'): 62,
#  ('siebie', 'subst'): 61,
#  ('pred', 'subst'): 61,
#  ('pact', 'brev'): 61,
#  ('prep', 'conj'): 60,
#  ('adj', 'winien'): 60,
#  ('brev', 'inf'): 60,
#  ('imps', 'inf'): 59,
#  ('adj', 'ppron3'): 59,
#  ('imps', 'adv'): 58,
#  ('fin', 'ppron3'): 57,
#  ('brev', 'prep'): 56,
#  ('adv', 'pcon'): 56,
#  ('brev', 'adv'): 56,
#  ('praet', 'conj'): 56,
#  ('pact', 'num'): 55,
#  ('interj', 'adj'): 53,
#  ('imps', 'praet'): 51,
#  ('pcon', 'pact'): 50,
#  ('prep', 'brev'): 50,
#  ('praet', 'pcon'): 50,
#  ('bedzie', 'ppas'): 49,
#  ('ppron3', 'adj'): 49,
#  ('inf', 'imps'): 48,
#  ('adv', 'brev'): 47,
#  ('prep', 'qub'): 47,
#  ('qub', 'qub'): 47,
#  ('pact', 'comp'): 47,
#  ('pcon', 'praet'): 46,
#  ('winien', 'ppas'): 46,
#  ('imps', 'pact'): 46,
#  ('pact', 'imps'): 46,
#  ('num', 'pact'): 45,
#  ('conj', 'qub'): 44,
#  ('num', 'num'): 44,
#  ('prep', 'num'): 42,
#  ('comp', 'inf'): 42,
#  ('praet', 'num'): 41,
#  ('num', 'praet'): 40,
#  ('ger', 'adja'): 40,
#  ('num', 'adv'): 39,
#  ('bedzie', 'praet'): 38,
#  ('adja', 'adja'): 38,
#  ('ger', 'pred'): 37,
#  ('ger', 'winien'): 36,
#  ('bedzie', 'subst'): 35,
#  ('pcon', 'prep'): 35,
#  ('comp', 'adv'): 35,
#  ('pred', 'adj'): 35,
#  ('praet', 'imps'): 34,
#  ('pact', 'ppron3'): 34,
#  ('num', 'inf'): 34,
#  ('ppron3', 'ppas'): 33,
#  ('brev', 'praet'): 33,
#  ('adv', 'comp'): 33,
#  ('prep', 'imps'): 33,
#  ('adj', 'xxx'): 32,
#  ('ppas', 'pred'): 32,
#  ('comp', 'pact'): 32,
#  ('comp', 'prep'): 31,
#  ('ppas', 'bedzie'): 30,
#  ('ppas', 'ppron3'): 30,
#  ('bedzie', 'inf'): 30,
#  ('praet', 'comp'): 29,
#  ('num', 'prep'): 29,
#  ('qub', 'conj'): 29,
#  ('fin', 'pred'): 29,
#  ('fin', 'adja'): 29,
#  ('brev', 'conj'): 29,
#  ('adja', 'ger'): 29,
#  ('xxx', 'adj'): 29,
#  ('ppas', 'siebie'): 28,
#  ('brev', 'qub'): 27,
#  ('comp', 'imps'): 27,
#  ('conj', 'conj'): 26,
#  ('conj', 'num'): 26,
#  ('prep', 'comp'): 26,
#  ('subst', 'siebie'): 26,
#  ('qub', 'imps'): 26,
#  ('interj', 'ger'): 26,
#  ('adj', 'bedzie'): 26,
#  ('qub', 'num'): 25,
#  ('ppas', 'winien'): 24,
#  ('conj', 'pcon'): 24,
#  ('inf', 'brev'): 24,
#  ('pred', 'ger'): 24,
#  ('adja', 'fin'): 23,
#  ('ppas', 'adja'): 23,
#  ('praet', 'brev'): 23,
#  ('bedzie', 'adj'): 23,
#  ('prep', 'pcon'): 23,
#  ('subst', 'impt'): 23,
#  ('ger', 'bedzie'): 22,
#  ('subst', 'pant'): 22,
#  ('adja', 'ppas'): 22,
#  ('adja', 'pact'): 22,
#  ('impt', 'subst'): 21,
#  ('prep', 'ppron3'): 21,
#  ('pred', 'ppas'): 21,
#  ('pred', 'fin'): 20,
#  ('fin', 'bedzie'): 20,
#  ('siebie', 'adj'): 20,
#  ('ppron3', 'fin'): 20,
#  ('brev', 'interj'): 19,
#  ('burk', 'subst'): 19,
#  ('conj', 'imps'): 19,
#  ('subst', 'burk'): 18,
#  ('pact', 'pred'): 18,
#  ('fin', 'winien'): 18,
#  ('pact', 'adja'): 18,
#  ('ppas', 'interj'): 17,
#  ('comp', 'qub'): 17,
#  ('inf', 'ppron3'): 17,
#  ('inf', 'bedzie'): 17,
#  ('imps', 'prep'): 17,
#  ('pcon', 'qub'): 17,
#  ('interj', 'pact'): 17,
#  ('qub', 'comp'): 16,
#  ('winien', 'subst'): 16,
#  ('pcon', 'comp'): 16,
#  ('num', 'conj'): 15,
#  ('interj', 'brev'): 15,
#  ('fin', 'siebie'): 15,
#  ('interj', 'fin'): 15,
#  ('pact', 'interj'): 15,
#  ('inf', 'pred'): 14,
#  ('pred', 'adv'): 14,
#  ('pcon', 'conj'): 14,
#  ('ger', 'interj'): 14,
#  ('siebie', 'ppas'): 14,
#  ('imps', 'pcon'): 14,
#  ('siebie', 'fin'): 14,
#  ('interj', 'ppas'): 13,
#  ('qub', 'pcon'): 13,
#  ('qub', 'brev'): 13,
#  ('brev', 'pcon'): 13,
#  ('inf', 'adja'): 13,
#  ('imps', 'qub'): 13,
#  ('inf', 'siebie'): 12,
#  ('pant', 'adj'): 12,
#  ('num', 'qub'): 12,
#  ('pact', 'winien'): 12,
#  ('num', 'pcon'): 11,
#  ('conj', 'brev'): 11,
#  ('prep', 'adja'): 11,
#  ('pred', 'praet'): 11,
#  ('subst', 'adjp'): 11,
#  ('adj', 'impt'): 11,
#  ('interj', 'interj'): 10,
#  ('conj', 'ppron3'): 10,
#  ('praet', 'pred'): 10,
#  ('ppron3', 'praet'): 10,
#  ('conj', 'comp'): 10,
#  ('pant', 'ger'): 10,
#  ('adjp', 'subst'): 10,
#  ('adj', 'numcol'): 10,
#  ('bedzie', 'fin'): 10,
#  ('comp', 'conj'): 10,
#  ('siebie', 'ger'): 10,
#  ('imps', 'conj'): 10,
#  ('adja', 'brev'): 10,
#  ('ppron12', 'subst'): 10,
#  ('adj', 'burk'): 10,
#  ('prep', 'siebie'): 9,
#  ('ger', 'impt'): 9,
#  ('praet', 'ppron3'): 9,
#  ('prep', 'pred'): 9,
#  ('pact', 'siebie'): 9,
#  ('brev', 'num'): 9,
#  ('imps', 'num'): 9,
#  ('interj', 'adv'): 9,
#  ('imps', 'comp'): 9,
#  ('adv', 'pred'): 9,
#  ('pant', 'subst'): 9,
#  ('xxx', 'brev'): 9,
#  ('impt', 'adj'): 9,
#  ('pred', 'qub'): 8,
#  ('pcon', 'imps'): 8,
#  ('ppron3', 'inf'): 8,
#  ('pant', 'fin'): 8,
#  ('brev', 'comp'): 8,
#  ('ppron3', 'pact'): 8,
#  ('ger', 'siebie'): 8,
#  ('ger', 'burk'): 8,
#  ('numcol', 'subst'): 8,
#  ('adv', 'adja'): 8,
#  ('subst', 'ppron12'): 8,
#  ('adv', 'winien'): 8,
#  ('adv', 'interj'): 8,
#  ('conj', 'adja'): 8,
#  ('adja', 'interj'): 7,
#  ('adv', 'ppron3'): 7,
#  ('winien', 'adv'): 7,
#  ('bedzie', 'ger'): 7,
#  ('subst', 'numcol'): 7,
#  ('ppron3', 'prep'): 7,
#  ('adjp', 'ger'): 7,
#  ('winien', 'adj'): 7,
#  ('ppron3', 'conj'): 7,
#  ('fin', 'pant'): 7,
#  ('fin', 'interj'): 7,
#  ('burk', 'adj'): 7,
#  ('brev', 'xxx'): 7,
#  ('interj', 'xxx'): 7,
#  ('adv', 'bedzie'): 7,
#  ('inf', 'winien'): 7,
#  ('prep', 'interj'): 7,
#  ('interj', 'adja'): 6,
#  ('praet', 'interj'): 6,
#  ('burk', 'ppas'): 6,
#  ('prep', 'winien'): 6,
#  ('bedzie', 'adv'): 6,
#  ('ppas', 'burk'): 6,
#  ('adj', 'adjp'): 6,
#  ('praet', 'siebie'): 6,
#  ('ppron3', 'adv'): 6,
#  ('adj', 'siebie'): 6,
#  ('impt', 'ger'): 6,
#  ('comp', 'pred'): 6,
#  ('num', 'imps'): 6,
#  ('num', 'brev'): 6,
#  ('comp', 'num'): 6,
#  ('conj', 'winien'): 6,
#  ('impt', 'ppas'): 6,
#  ('pcon', 'ppron3'): 6,
#  ('siebie', 'pact'): 5,
#  ('num', 'comp'): 5,
#  ('siebie', 'adv'): 5,
#  ('numcol', 'fin'): 5,
#  ('adja', 'inf'): 5,
#  ('qub', 'pred'): 5,
#  ('comp', 'pcon'): 5,
#  ('adja', 'adv'): 5,
#  ('conj', 'pred'): 5,
#  ('prep', 'bedzie'): 5,
#  ('winien', 'pact'): 5,
#  ('pred', 'pact'): 5,
#  ('comp', 'brev'): 5,
#  ('siebie', 'prep'): 5,
#  ('brev', 'pred'): 5,
#  ('pant', 'praet'): 5,
#  ('ppron12', 'fin'): 5,
#  ('xxx', 'ppas'): 5,
#  ('bedzie', 'pact'): 5,
#  ('siebie', 'praet'): 5,
#  ('adja', 'prep'): 5,
#  ('ger', 'pant'): 4,
#  ('praet', 'adja'): 4,
#  ('adja', 'praet'): 4,
#  ('fin', 'numcol'): 4,
#  ('qub', 'ppron3'): 4,
#  ('adj', 'pant'): 4,
#  ('qub', 'bedzie'): 4,
#  ('ppron3', 'qub'): 4,
#  ('burk', 'ger'): 4,
#  ('adjp', 'fin'): 4,
#  ('subst', 'adjc'): 4,
#  ('imps', 'brev'): 4,
#  ('impt', 'inf'): 4,
#  ('ppas', 'pant'): 4,
#  ('siebie', 'inf'): 4,
#  ('ppron12', 'inf'): 4,
#  ('praet', 'aglt'): 4,
#  ('numcol', 'adj'): 4,
#  ('adjp', 'adj'): 4,
#  ('winien', 'qub'): 4,
#  ('ppas', 'xxx'): 4,
#  ('brev', 'adja'): 4,
#  ('adja', 'xxx'): 4,
#  ('xxx', 'pact'): 4,
#  ('ppas', 'adjp'): 3,
#  ('num', 'adja'): 3,
#  ('interj', 'praet'): 3,
#  ('adv', 'ppron12'): 3,
#  ('fin', 'impt'): 3,
#  ('siebie', 'pcon'): 3,
#  ('pcon', 'num'): 3,
#  ('prep', 'pant'): 3,
#  ('comp', 'bedzie'): 3,
#  ('ger', 'adjp'): 3,
#  ('depr', 'subst'): 3,
#  ('adjc', 'inf'): 3,
#  ('praet', 'bedzie'): 3,
#  ('praet', 'winien'): 3,
#  ('ppas', 'impt'): 3,
#  ('adja', 'qub'): 3,
#  ('num', 'pred'): 3,
#  ('adjp', 'pact'): 3,
#  ('pcon', 'pred'): 3,
#  ('interj', 'conj'): 3,
#  ('interj', 'prep'): 3,
#  ('brev', 'bedzie'): 3,
#  ('xxx', 'interj'): 3,
#  ('interj', 'num'): 3,
#  ('adja', 'conj'): 3,
#  ('imps', 'pred'): 3,
#  ('adv', 'impt'): 3,
#  ('winien', 'ger'): 3,
#  ('siebie', 'qub'): 3,
#  ('interj', 'qub'): 3,
#  ('xxx', 'fin'): 3,
#  ('aglt', 'adj'): 3,
#  ('adv', 'xxx'): 3,
#  ('brev', 'impt'): 3,
#  ('xxx', 'adja'): 3,
#  ('aglt', 'subst'): 3,
#  ('pcon', 'brev'): 3,
#  ('comp', 'comp'): 3,
#  ('impt', 'praet'): 2,
#  ('ppron12', 'adv'): 2,
#  ('impt', 'fin'): 2,
#  ('adjp', 'ppas'): 2,
#  ('comp', 'ppron3'): 2,
#  ('ppron3', 'brev'): 2,
#  ('subst', 'depr'): 2,
#  ('prep', 'adjp'): 2,
#  ('siebie', 'num'): 2,
#  ('burk', 'praet'): 2,
#  ('num', 'pant'): 2,
#  ('pant', 'prep'): 2,
#  ('interj', 'inf'): 2,
#  ('pcon', 'winien'): 2,
#  ('ppron12', 'adj'): 2,
#  ('interj', 'impt'): 2,
#  ('conj', 'impt'): 2,
#  ('burk', 'inf'): 2,
#  ('pant', 'pact'): 2,
#  ('adv', 'pant'): 2,
#  ('adj', 'ppron12'): 2,
#  ('fin', 'aglt'): 2,
#  ('ger', 'xxx'): 2,
#  ('ppron12', 'ger'): 2,
#  ('burk', 'fin'): 2,
#  ('pact', 'adjp'): 2,
#  ('adja', 'pcon'): 2,
#  ('inf', 'interj'): 2,
#  ('fin', 'burk'): 2,
#  ('pred', 'conj'): 2,
#  ('inf', 'pant'): 2,
#  ('adja', 'bedzie'): 2,
#  ('pred', 'comp'): 2,
#  ('conj', 'bedzie'): 2,
#  ('adv', 'siebie'): 2,
#  ('ger', 'ppron12'): 2,
#  ('conj', 'numcol'): 2,
#  ('qub', 'adja'): 2,
#  ('adja', 'ppron12'): 2,
#  ('ppron12', 'brev'): 2,
#  ('xxx', 'prep'): 2,
#  ('ger', 'aglt'): 2,
#  ('qub', 'winien'): 2,
#  ('inf', 'impt'): 2,
#  ('impt', 'pact'): 2,
#  ('imps', 'ppron3'): 2,
#  ('brev', 'winien'): 2,
#  ('adja', 'comp'): 2,
#  ('pred', 'prep'): 2,
#  ('pact', 'burk'): 2,
#  ('imps', 'pant'): 2,
#  ('burk', 'adv'): 2,
#  ('praet', 'pant'): 2,
#  ('pact', 'bedzie'): 2,
#  ('xxx', 'conj'): 2,
#  ('numcol', 'ppas'): 2,
#  ('pcon', 'bedzie'): 2,
#  ('brev', 'imps'): 2,
#  ('adj', 'interp'): 1,
#  ('xxx', 'ger'): 1,
#  ('siebie', 'adja'): 1,
#  ('pcon', 'adjp'): 1,
#  ('pred', 'pred'): 1,
#  ('ppas', 'interp'): 1,
#  ('interp', 'subst'): 1,
#  ('burk', 'prep'): 1,
#  ('adja', 'impt'): 1,
#  ('praet', 'numcol'): 1,
#  ('numcol', 'praet'): 1,
#  ('siebie', 'comp'): 1,
#  ('ppron12', 'impt'): 1,
#  ('comp', 'adja'): 1,
#  ('qub', 'pant'): 1,
#  ('ppron3', 'num'): 1,
#  ('ppron12', 'bedzie'): 1,
#  ('num', 'siebie'): 1,
#  ('adjc', 'praet'): 1,
#  ('winien', 'conj'): 1,
#  ('impt', 'prep'): 1,
#  ('fin', 'ppron12'): 1,
#  ('impt', 'ppron3'): 1,
#  ('siebie', 'conj'): 1,
#  ('adv', 'burk'): 1,
#  ('comp', 'winien'): 1,
#  ('fin', 'adjp'): 1,
#  ('bedzie', 'conj'): 1,
#  ('interj', 'interp'): 1,
#  ('interp', 'brev'): 1,
#  ('adjc', 'adj'): 1,
#  ('pred', 'pcon'): 1,
#  ('pact', 'depr'): 1,
#  ('pant', 'comp'): 1,
#  ('pact', 'impt'): 1,
#  ('prep', 'burk'): 1,
#  ('prep', 'xxx'): 1,
#  ('ppas', 'ppron12'): 1,
#  ('pact', 'ppron12'): 1,
#  ('pant', 'pcon'): 1,
#  ('adja', 'depr'): 1,
#  ('depr', 'ger'): 1,
#  ('ppron3', 'winien'): 1,
#  ('ppron3', 'comp'): 1,
#  ('pact', 'adjc'): 1,
#  ('fin', 'adjc'): 1,
#  ('adjc', 'qub'): 1,
#  ('conj', 'xxx'): 1,
#  ('subst', 'interp'): 1,
#  ('interp', 'adj'): 1,
#  ('impt', 'imps'): 1,
#  ('adjp', 'qub'): 1,
#  ('pant', 'imps'): 1,
#  ('imps', 'siebie'): 1,
#  ('prep', 'numcol'): 1,
#  ('pred', 'interj'): 1,
#  ('num', 'bedzie'): 1,
#  ('bedzie', 'pcon'): 1,
#  ('num', 'winien'): 1,
#  ('praet', 'burk'): 1,
#  ('siebie', 'brev'): 1,
#  ('depr', 'adj'): 1,
#  ('ppron3', 'imps'): 1,
#  ('numcol', 'num'): 1,
#  ('comp', 'numcol'): 1,
#  ('xxx', 'pred'): 1,
#  ('imps', 'xxx'): 1,
#  ('xxx', 'qub'): 1,
#  ('pact', 'pant'): 1,
#  ('qub', 'impt'): 1,
#  ('imps', 'bedzie'): 1,
#  ('winien', 'prep'): 1,
#  ('interj', 'winien'): 1,
#  ('adjp', 'praet'): 1,
#  ('interj', 'comp'): 1,
#  ('conj', 'interj'): 1,
#  ('impt', 'comp'): 1,
#  ('siebie', 'siebie'): 1,
#  ('pred', 'num'): 1,
#  ('num', 'adjp'): 1,
#  ('praet', 'adjc'): 1,
#  ('adj', 'depr'): 1,
#  ('pant', 'adv'): 1,
#  ('adjc', 'fin'): 1,
#  ('brev', 'depr'): 1,
#  ('praet', 'adjp'): 1,
#  ('burk', 'pact'): 1,
#  ('pred', 'bedzie'): 1,
#  ('siebie', 'winien'): 1,
#  ('pant', 'ppron3'): 1,
#  ('interj', 'ppron3'): 1,
#  ('adjc', 'ppas'): 1,
#  ('fin', 'depr'): 1,
#  ('depr', 'adv'): 1,
#  ('impt', 'pcon'): 1,
#  ('prep', 'adjc'): 1,
#  ('pred', 'ppron3'): 1,
#  ('xxx', 'ppron12'): 1,
#  ('ppron12', 'ppas'): 1,
#  ('conj', 'pant'): 1,
#  ('praet', 'depr'): 1,
#  ('depr', 'praet'): 1,
#  ('num', 'numcol'): 1,
#  ('numcol', 'adv'): 1,
#  ('burk', 'brev'): 1,
#  ('conj', 'siebie'): 1,
#  ('numcol', 'inf'): 1,
#  ('siebie', 'burk'): 1,
#  ('adv', 'adjp'): 1,
#  ('adjp', 'adv'): 1,
#  ('qub', 'siebie'): 1,
#  ('imps', 'winien'): 1,
#  ('winien', 'pcon'): 1,
#  ('pant', 'ppas'): 1,
#  ('adj', 'aglt'): 1,
#  ('aglt', 'ppas'): 1,
#  ('adja', 'ppron3'): 1,
#  ('bedzie', 'num'): 1,
#  ('adv', 'numcol'): 1,
#  ('xxx', 'inf'): 1,
#  ('brev', 'ppron3'): 1,
#  ('pcon', 'interj'): 1,
#  ('pcon', 'adja'): 1}

# %% [markdown]
# ## Select the 10 largest partitions (partitions with the largest number of entries).

# %%
largest_partitions = list(sorted_partitions.keys())[:10]

# %% [markdown]
# ## Use the computed LLR measure to select 5 bigrams for each of the largest categories.

# %%
for partition in largest_partitions:
    partitioned_bigrams = Counter({x: count for x, count in bigrams_total.items() if x[0][1] == partition[0] and x[1][1] == partition[1]})
    bigrams_partitioned_llr = {bigram: llr2(bigram[0], bigram[1]) for bigram, _  in partitioned_bigrams.items()}
    bigrams_partitioned_llr_top5 = Counter(bigrams_partitioned_llr).most_common()[:5]
    print_table(bigrams_partitioned_llr_top5, '(' + partition[0] + ', ' + partition[1] + ')')
# Out:
# ╒════════════════════════════════════════════╤═════════╕
# │ bigram (subst, subst)                      │     LLR │
# ╞════════════════════════════════════════════╪═════════╡
# │ (('przepis', 'subst'), ('mowa', 'subst'))  │ 2266.16 │
# ├────────────────────────────────────────────┼─────────┤
# │ (('mowa', 'subst'), ('przepis', 'subst'))  │ 2266.16 │
# ├────────────────────────────────────────────┼─────────┤
# │ (('mowa', 'subst'), ('sprawa', 'subst'))   │ 2131.15 │
# ├────────────────────────────────────────────┼─────────┤
# │ (('mowa', 'subst'), ('minister', 'subst')) │ 1997.31 │
# ├────────────────────────────────────────────┼─────────┤
# │ (('osoba', 'subst'), ('mowa', 'subst'))    │ 1952.01 │
# ╘════════════════════════════════════════════╧═════════╛
# ╒═════════════════════════════════════════╤═════════╕
# │ bigram (adj, subst)                     │     LLR │
# ╞═════════════════════════════════════════╪═════════╡
# │ (('który', 'adj'), ('mowa', 'subst'))   │ 4000.84 │
# ├─────────────────────────────────────────┼─────────┤
# │ (('który', 'adj'), ('sprawa', 'subst')) │ 3753.9  │
# ├─────────────────────────────────────────┼─────────┤
# │ (('który', 'adj'), ('organ', 'subst'))  │ 2553.75 │
# ├─────────────────────────────────────────┼─────────┤
# │ (('ten', 'adj'), ('mowa', 'subst'))     │ 2477.93 │
# ├─────────────────────────────────────────┼─────────┤
# │ (('który', 'adj'), ('prawo', 'subst'))  │ 2387.53 │
# ╘═════════════════════════════════════════╧═════════╛
# ╒════════════════════════════════════════════╤═════════╕
# │ bigram (subst, adj)                        │     LLR │
# ╞════════════════════════════════════════════╪═════════╡
# │ (('brzmienie', 'subst'), ('który', 'adj')) │ 4060.25 │
# ├────────────────────────────────────────────┼─────────┤
# │ (('przepis', 'subst'), ('który', 'adj'))   │ 4000.23 │
# ├────────────────────────────────────────────┼─────────┤
# │ (('sprawa', 'subst'), ('który', 'adj'))    │ 3701.04 │
# ├────────────────────────────────────────────┼─────────┤
# │ (('osoba', 'subst'), ('który', 'adj'))     │ 3190.54 │
# ├────────────────────────────────────────────┼─────────┤
# │ (('wyraz', 'subst'), ('który', 'adj'))     │ 2737.09 │
# ╘════════════════════════════════════════════╧═════════╛
# ╒════════════════════════════════════════════════╤══════════╕
# │ bigram (ger, subst)                            │      LLR │
# ╞════════════════════════════════════════════════╪══════════╡
# │ (('wejść', 'ger'), ('życie', 'subst'))         │ 1276.56  │
# ├────────────────────────────────────────────────┼──────────┤
# │ (('zasięgnąć', 'ger'), ('opinia', 'subst'))    │ 1069.5   │
# ├────────────────────────────────────────────────┼──────────┤
# │ (('rozpatrzyć', 'ger'), ('poprawka', 'subst')) │  866.412 │
# ├────────────────────────────────────────────────┼──────────┤
# │ (('wykonywać', 'ger'), ('mowa', 'subst'))      │  599.104 │
# ├────────────────────────────────────────────────┼──────────┤
# │ (('prowadzić', 'ger'), ('mowa', 'subst'))      │  372.184 │
# ╘════════════════════════════════════════════════╧══════════╛
# ╒═════════════════════════════════════════════╤═════════╕
# │ bigram (subst, ger)                         │     LLR │
# ╞═════════════════════════════════════════════╪═════════╡
# │ (('sprawa', 'subst'), ('wykonywać', 'ger')) │ 334.681 │
# ├─────────────────────────────────────────────┼─────────┤
# │ (('osoba', 'subst'), ('wykonywać', 'ger'))  │ 305.891 │
# ├─────────────────────────────────────────────┼─────────┤
# │ (('wyraz', 'subst'), ('wykonywać', 'ger'))  │ 243.018 │
# ├─────────────────────────────────────────────┼─────────┤
# │ (('sprawa', 'subst'), ('wydać', 'ger'))     │ 191.764 │
# ├─────────────────────────────────────────────┼─────────┤
# │ (('prawo', 'subst'), ('wykonywać', 'ger'))  │ 174.127 │
# ╘═════════════════════════════════════════════╧═════════╛
# ╒══════════════════════════════════════════════╤═════════╕
# │ bigram (adj, adj)                            │     LLR │
# ╞══════════════════════════════════════════════╪═════════╡
# │ (('ten', 'adj'), ('który', 'adj'))           │ 4358.92 │
# ├──────────────────────────────────────────────┼─────────┤
# │ (('który', 'adj'), ('właściwy', 'adj'))      │ 3169.7  │
# ├──────────────────────────────────────────────┼─────────┤
# │ (('inny', 'adj'), ('który', 'adj'))          │ 2710.07 │
# ├──────────────────────────────────────────────┼─────────┤
# │ (('polski', 'adj'), ('który', 'adj'))        │ 1684.19 │
# ├──────────────────────────────────────────────┼─────────┤
# │ (('przejściowy', 'adj'), ('końcowy', 'adj')) │ 1495.35 │
# ╘══════════════════════════════════════════════╧═════════╛
# ╒══════════════════════════════════════════╤═════════╕
# │ bigram (subst, fin)                      │     LLR │
# ╞══════════════════════════════════════════╪═════════╡
# │ (('mowa', 'subst'), ('być', 'fin'))      │ 2376.18 │
# ├──────────────────────────────────────────┼─────────┤
# │ (('mowa', 'subst'), ('móc', 'fin'))      │ 1907.73 │
# ├──────────────────────────────────────────┼─────────┤
# │ (('brzmienie', 'subst'), ('być', 'fin')) │ 1529.29 │
# ├──────────────────────────────────────────┼─────────┤
# │ (('przepis', 'subst'), ('być', 'fin'))   │ 1466.76 │
# ├──────────────────────────────────────────┼─────────┤
# │ (('sprawa', 'subst'), ('być', 'fin'))    │ 1413.41 │
# ╘══════════════════════════════════════════╧═════════╛
# ╒════════════════════════════════════════════════╤══════════╕
# │ bigram (subst, ppas)                           │      LLR │
# ╞════════════════════════════════════════════════╪══════════╡
# │ (('mowa', 'subst'), ('określić', 'ppas'))      │ 1420.92  │
# ├────────────────────────────────────────────────┼──────────┤
# │ (('brzmienie', 'subst'), ('określić', 'ppas')) │  865.295 │
# ├────────────────────────────────────────────────┼──────────┤
# │ (('przepis', 'subst'), ('określić', 'ppas'))   │  844.084 │
# ├────────────────────────────────────────────────┼──────────┤
# │ (('sprawa', 'subst'), ('określić', 'ppas'))    │  788.093 │
# ├────────────────────────────────────────────────┼──────────┤
# │ (('minister', 'subst'), ('określić', 'ppas'))  │  762.711 │
# ╘════════════════════════════════════════════════╧══════════╛
# ╒═══════════════════════════════════════════════╤══════════╕
# │ bigram (ppas, subst)                          │      LLR │
# ╞═══════════════════════════════════════════════╪══════════╡
# │ (('określić', 'ppas'), ('mowa', 'subst'))     │ 1420.92  │
# ├───────────────────────────────────────────────┼──────────┤
# │ (('określić', 'ppas'), ('ustawa', 'subst'))   │ 1222.75  │
# ├───────────────────────────────────────────────┼──────────┤
# │ (('określić', 'ppas'), ('sprawa', 'subst'))   │  799.398 │
# ├───────────────────────────────────────────────┼──────────┤
# │ (('określić', 'ppas'), ('minister', 'subst')) │  731.853 │
# ├───────────────────────────────────────────────┼──────────┤
# │ (('określić', 'ppas'), ('przepis', 'subst'))  │  631.594 │
# ╘═══════════════════════════════════════════════╧══════════╛
# ╒═══════════════════════════════════════════╤══════════╕
# │ bigram (fin, subst)                       │      LLR │
# ╞═══════════════════════════════════════════╪══════════╡
# │ (('wchodzić', 'fin'), ('życie', 'subst')) │ 2600.68  │
# ├───────────────────────────────────────────┼──────────┤
# │ (('być', 'fin'), ('mowa', 'subst'))       │ 2141.38  │
# ├───────────────────────────────────────────┼──────────┤
# │ (('być', 'fin'), ('minister', 'subst'))   │ 1314.61  │
# ├───────────────────────────────────────────┼──────────┤
# │ (('być', 'fin'), ('osoba', 'subst'))      │ 1196.62  │
# ├───────────────────────────────────────────┼──────────┤
# │ (('być', 'fin'), ('organ', 'subst'))      │  913.854 │
# ╘═══════════════════════════════════════════╧══════════╛

# %% [markdown]
# ## Using the results from the previous step answer the following questions:

# %% [markdown]
# ### What types of bigrams have been found?

# %% [markdown]
# ### Which of the category-pairs indicate valuable multiword expressions? Do they have anything in common?

# %% [markdown]
# ### Which signal: LLR score or syntactic category is more useful for determining genuine multiword expressions?

# %% [markdown]
# ### Can you describe a different use-case where the morphosyntactic category is useful for resolving a real-world problem?
